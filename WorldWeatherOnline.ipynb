# %%
import requests
import json
import pandas as pd

# %%
#Here are a few coordinates, and you have to find the fortnightly average temperature for these coordinates(longitude and latitude):
lat_long_deg_min_sec = [
('37° 52\' 5.336" S', '144° 55\' 40.452" E'),
('38° 19\' 57.125" S', '144° 54\' 17.831" E'),
('38° 51\' 34.878" S', '142° 54\' 18.281" E'), 
('37° 50\' 33.481" S', '135° 38\' 20.388" E'),
('35° 5\' 50.501" S', '128° 48\' 40.243" E'), 
('34° 20\' 7.398" S', '121° 35\' 19.757" E'),
('34° 55\' 34.99" S', '118° 45\' 4.596" E'), 
('35° 3\' 36.441" S', '115° 51\' 54.355" E'),
('30° 45\' 16.173" S', '110° 26\' 25.532" E'),
('12° 5\' 45.683" S', '106° 25\' 8.984" E'),
('6° 18\' 54.271" S', '105° 33\' 56.07" E'), 
('5° 15\' 14.261" S', '106° 13\' 37.411" E'),
('3° 42\' 37.526" S', '107° 35\' 13.608" E'), 
('2° 0\' 50.122" S', '107° 12\' 50.324" E'),
('0° 42\' 51.809" N', '105° 19\' 28.118" E'), 
('1° 18\' 56.371" N', '104° 19\' 31.582" E'),
('1° 13\' 14.328" N', '103° 52\' 6.734" E')
]

# %%
import re
def convert(tude):
    multiplier = 1 if tude[-1] in ['N', 'E'] else -1
    tude = re.split('° |\' |" ', tude)
    #print(tude)
    return multiplier * sum(float(x) / 60 ** n for n, x in enumerate(tude[:-1]))

# %%
lat_long_dec = []

for lat_long in lat_long_deg_min_sec:
    lat = convert(lat_long[0])
    long = convert(lat_long[1])
    lat_long_dec.append((lat, long))

print(lat_long_dec)
# Out:
# [(-37.86814888888889, 144.92790333333332), (-38.33253472222223, 144.90495305555555), (-38.85968833333334, 142.90507805555555), (-37.84263361111111, 135.63899666666666), (-35.09736138888889, 128.81117861111113), (-34.335388333333334, 121.58882138888889), (-34.92638611111111, 118.75127666666667), (-35.0601225, 115.86509861111111), (-30.7544925, 110.44042555555556), (-12.096023055555555, 106.41916222222223), (-6.315075277777778, 105.565575), (-5.2539613888888885, 106.22705861111112), (-3.710423888888889, 107.58711333333333), (-2.0139227777777777, 107.21397888888889), (0.7143913888888889, 105.32447722222221), (1.3156586111111113, 104.32543944444444), (1.2206466666666669, 103.86853722222222)]

# %%
CLIENT_ID = '50579375f5d1481e85e161222211406'

for lat, long in lat_long_dec:
    print(lat, long, '-----------------------------------------------------------')

    # create the API request URL
    url = 'https://api.worldweatheronline.com/premium/v1/weather.ashx?key={}&q={},{}&format=json&num_of_days={}'.format(
        CLIENT_ID,
        lat, 
        long, 
        5)
    
    response  = requests.get(url)
    forecasts  = response.json()
    
    try:
        print("Date: {}, Max Temperature: {}".format(forecasts['data']['weather'][0]['date'], forecasts['data']['weather'][0]['maxtempC']))
    except:
        print('Empty Response')
# Out:
# -37.86814888888889 144.92790333333332 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 15
# -38.33253472222223 144.90495305555555 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 15
# -38.85968833333334 142.90507805555555 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 12
# -37.84263361111111 135.63899666666666 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 13
# -35.09736138888889 128.81117861111113 -----------------------------------------------------------
# Empty Response
# -34.335388333333334 121.58882138888889 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 14
# -34.92638611111111 118.75127666666667 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 12
# -35.0601225 115.86509861111111 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 13
# -30.7544925 110.44042555555556 -----------------------------------------------------------
# Empty Response
# -12.096023055555555 106.41916222222223 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 27
# -6.315075277777778 105.565575 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 27
# -5.2539613888888885 106.22705861111112 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 28
# -3.710423888888889 107.58711333333333 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 29
# -2.0139227777777777 107.21397888888889 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 29
# 0.7143913888888889 105.32447722222221 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 31
# 1.3156586111111113 104.32543944444444 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 31
# 1.2206466666666669 103.86853722222222 -----------------------------------------------------------
# Date: 2021-06-24, Max Temperature: 29

# %%
# !pip install wwo-hist
# Out:
# Requirement already satisfied: wwo-hist in c:\ide\anaconda3\envs\python38\lib\site-packages (0.0.7)

# %%
from wwo_hist import retrieve_hist_data

# %%
frequency=24
start_date = '1-JUN-2016'
end_date = '1-AUG-2016'
api_key = CLIENT_ID



hist_weather_data_df = pd.DataFrame()

for lat, long in lat_long_dec:
    location_list = []
    
    location_list.append('{},{}'.format(lat, long))
    
    try:
        hist_weather_data_list = retrieve_hist_data(api_key,
                                    location_list,
                                    start_date,
                                    end_date,
                                    frequency,
                                    location_label = False,
                                    export_csv = False,
                                    store_df = True)
        
        # hist_weather_data_list is a list of datframes. Since we are making one call for one location, we get the first dataframe as the first element of the list
        hist_weather_data_df = hist_weather_data_df.append(hist_weather_data_list[0])
    
    except:
        print('Unable to find any matching weather for location {}'.format(location_list))
# Out:
# Retrieving weather data for -37.86814888888889,144.92790333333332
#
#
# Currently retrieving data for -37.86814888888889,144.92790333333332: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.408148
# Currently retrieving data for -37.86814888888889,144.92790333333332: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.844624
# Currently retrieving data for -37.86814888888889,144.92790333333332: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.157949
#
#
# Retrieving weather data for -38.33253472222223,144.90495305555555
#
#
# Currently retrieving data for -38.33253472222223,144.90495305555555: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.382130
# Currently retrieving data for -38.33253472222223,144.90495305555555: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.213461
# Currently retrieving data for -38.33253472222223,144.90495305555555: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.504483
#
#
# Retrieving weather data for -38.85968833333334,142.90507805555555
#
#
# Currently retrieving data for -38.85968833333334,142.90507805555555: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.715530
# Currently retrieving data for -38.85968833333334,142.90507805555555: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.261000
# Currently retrieving data for -38.85968833333334,142.90507805555555: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.531094
#
#
# Retrieving weather data for -37.84263361111111,135.63899666666666
#
#
# Currently retrieving data for -37.84263361111111,135.63899666666666: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.410332
# Currently retrieving data for -37.84263361111111,135.63899666666666: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.881926
# Currently retrieving data for -37.84263361111111,135.63899666666666: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.198706
#
#
# Retrieving weather data for -35.09736138888889,128.81117861111113
#
#
# Currently retrieving data for -35.09736138888889,128.81117861111113: from 2016-06-01 to 2016-06-30
# Unable to find any matching weather for location ['-35.09736138888889,128.81117861111113']
#
#
# Retrieving weather data for -34.335388333333334,121.58882138888889
#
#
# Currently retrieving data for -34.335388333333334,121.58882138888889: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.338128
# Currently retrieving data for -34.335388333333334,121.58882138888889: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.830879
# Currently retrieving data for -34.335388333333334,121.58882138888889: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.127438
#
#
# Retrieving weather data for -34.92638611111111,118.75127666666667
#
#
# Currently retrieving data for -34.92638611111111,118.75127666666667: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.456946
# Currently retrieving data for -34.92638611111111,118.75127666666667: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.912446
# Currently retrieving data for -34.92638611111111,118.75127666666667: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.189288
#
#
# Retrieving weather data for -35.0601225,115.86509861111111
#
#
# Currently retrieving data for -35.0601225,115.86509861111111: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.376716
# Currently retrieving data for -35.0601225,115.86509861111111: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.803586
# Currently retrieving data for -35.0601225,115.86509861111111: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.067881
#
#
# Retrieving weather data for -30.7544925,110.44042555555556
#
#
# Currently retrieving data for -30.7544925,110.44042555555556: from 2016-06-01 to 2016-06-30
# Unable to find any matching weather for location ['-30.7544925,110.44042555555556']
#
#
# Retrieving weather data for -12.096023055555555,106.41916222222223
#
#
# Currently retrieving data for -12.096023055555555,106.41916222222223: from 2016-06-01 to 2016-06-30
# Unable to find any matching weather for location ['-12.096023055555555,106.41916222222223']
#
#
# Retrieving weather data for -6.315075277777778,105.565575
#
#
# Currently retrieving data for -6.315075277777778,105.565575: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.483648
# Currently retrieving data for -6.315075277777778,105.565575: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.030551
# Currently retrieving data for -6.315075277777778,105.565575: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.333282
#
#
# Retrieving weather data for -5.2539613888888885,106.22705861111112
#
#
# Currently retrieving data for -5.2539613888888885,106.22705861111112: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.390528
# Currently retrieving data for -5.2539613888888885,106.22705861111112: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.210338
# Currently retrieving data for -5.2539613888888885,106.22705861111112: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.438481
#
#
# Retrieving weather data for -3.710423888888889,107.58711333333333
#
#
# Currently retrieving data for -3.710423888888889,107.58711333333333: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.198408
# Currently retrieving data for -3.710423888888889,107.58711333333333: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.576503
# Currently retrieving data for -3.710423888888889,107.58711333333333: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:02.826278
#
#
# Retrieving weather data for -2.0139227777777777,107.21397888888889
#
#
# Currently retrieving data for -2.0139227777777777,107.21397888888889: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.365662
# Currently retrieving data for -2.0139227777777777,107.21397888888889: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.819677
# Currently retrieving data for -2.0139227777777777,107.21397888888889: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.120808
#
#
# Retrieving weather data for 0.7143913888888889,105.32447722222221
#
#
# Currently retrieving data for 0.7143913888888889,105.32447722222221: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.376816
# Currently retrieving data for 0.7143913888888889,105.32447722222221: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.770501
# Currently retrieving data for 0.7143913888888889,105.32447722222221: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.080765
#
#
# Retrieving weather data for 1.3156586111111113,104.32543944444444
#
#
# Currently retrieving data for 1.3156586111111113,104.32543944444444: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.371319
# Currently retrieving data for 1.3156586111111113,104.32543944444444: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.757506
# Currently retrieving data for 1.3156586111111113,104.32543944444444: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.004103
#
#
# Retrieving weather data for 1.2206466666666669,103.86853722222222
#
#
# Currently retrieving data for 1.2206466666666669,103.86853722222222: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:01.413806
# Currently retrieving data for 1.2206466666666669,103.86853722222222: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.933150
# Currently retrieving data for 1.2206466666666669,103.86853722222222: from 2016-08-01 to 2016-08-01
# Time elapsed (hh:mm:ss.ms) 0:00:03.288866

# %%
hist_weather_data_df['date_time'] = pd.to_datetime(hist_weather_data_df['date_time'])

# %%
hist_weather_data_df.reset_index(inplace=True, drop=True)
hist_weather_data_df
# Out:
#      date_time maxtempC mintempC totalSnow_cm sunHour uvIndex  \
# 0   2016-06-01       14        9          0.0     7.0       3
# 1   2016-06-02       16       10          0.0     8.7       4
# 2   2016-06-03       15        9          0.0     8.7       3
# 3   2016-06-04       15       12          0.0     3.7       3
# 4   2016-06-05       15       12          0.0     3.7       3
# ..         ...      ...      ...          ...     ...     ...
# 863 2016-07-28       32       27          0.0    11.6       7
# 864 2016-07-29       32       26          0.0    11.6       7
# 865 2016-07-30       33       26          0.0    11.6       7
# 866 2016-07-31       33       26          0.0    11.6       7
# 867 2016-08-01       32       26          0.0    10.2       7
#
#     moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                  12  02:25 AM  02:30 PM  07:27 AM  ...           13
# 1                   4  03:34 AM  03:10 PM  07:28 AM  ...            8
# 2                   0  04:44 AM  03:53 PM  07:28 AM  ...           13
# 3                   0  05:55 AM  04:41 PM  07:29 AM  ...           12
# 4                   0  07:03 AM  05:33 PM  07:30 AM  ...           12
# ..                ...       ...       ...       ...  ...          ...
# 863                34  12:38 AM  01:06 PM  06:06 AM  ...           13
# 864                26  01:33 AM  02:02 PM  06:06 AM  ...           12
# 865                19  02:29 AM  02:59 PM  06:06 AM  ...            9
# 866                15  03:26 AM  03:57 PM  06:06 AM  ...            8
# 867                 5  04:23 AM  04:53 PM  06:06 AM  ...           11
#
#     cloudcover humidity precipMM pressure tempC visibility winddirDegree  \
# 0           64       80      0.4     1025    14          9           178
# 1            6       75      0.0     1027    16         10           124
# 2           33       78      1.1     1024    15          9           105
# 3           90       92     12.3     1015    15          6           135
# 4           89       90      0.9     1005    15          8           236
# ..         ...      ...      ...      ...   ...        ...           ...
# 863         33       69      1.8     1009    32         10           169
# 864         23       70      1.5     1009    32         10           177
# 865         27       70      2.2     1009    33         10           158
# 866         29       72      7.2     1009    33         10           160
# 867         41       68      4.9     1009    32          9           181
#
#     windspeedKmph                               location
# 0               8  -37.86814888888889,144.92790333333332
# 1               5  -37.86814888888889,144.92790333333332
# 2               9  -37.86814888888889,144.92790333333332
# 3               8  -37.86814888888889,144.92790333333332
# 4               8  -37.86814888888889,144.92790333333332
# ..            ...                                    ...
# 863             9  1.2206466666666669,103.86853722222222
# 864             9  1.2206466666666669,103.86853722222222
# 865             7  1.2206466666666669,103.86853722222222
# 866             6  1.2206466666666669,103.86853722222222
# 867             8  1.2206466666666669,103.86853722222222
#
# [868 rows x 25 columns]

# %%
grouped = hist_weather_data_df.groupby('location')
grouped

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\ide\anaconda3\envs\python38\lib\site-packages (0.12.1)
# Requirement already satisfied: branca>=0.3.0 in c:\ide\anaconda3\envs\python38\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: numpy in c:\ide\anaconda3\envs\python38\lib\site-packages (from folium) (1.19.1)
# Requirement already satisfied: jinja2>=2.9 in c:\ide\anaconda3\envs\python38\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in c:\ide\anaconda3\envs\python38\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\ide\anaconda3\envs\python38\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\ide\anaconda3\envs\python38\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\ide\anaconda3\envs\python38\lib\site-packages (from requests->folium) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\ide\anaconda3\envs\python38\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\ide\anaconda3\envs\python38\lib\site-packages (from requests->folium) (2020.12.5)

# %%
# !pip install vincent
# Out:
# Requirement already satisfied: vincent in c:\ide\anaconda3\envs\python38\lib\site-packages (0.4.4)
# Requirement already satisfied: pandas in c:\ide\anaconda3\envs\python38\lib\site-packages (from vincent) (1.1.1)
# Requirement already satisfied: pytz>=2017.2 in c:\ide\anaconda3\envs\python38\lib\site-packages (from pandas->vincent) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\ide\anaconda3\envs\python38\lib\site-packages (from pandas->vincent) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\ide\anaconda3\envs\python38\lib\site-packages (from pandas->vincent) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\ide\anaconda3\envs\python38\lib\site-packages (from python-dateutil>=2.7.3->pandas->vincent) (1.15.0)

# %%
import folium
import vincent

# To initialize vincent in the notebook
vincent.core.initialize_notebook()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>

# %%
m = folium.Map(start_zoom=10)

i = 0

for name, group in grouped:
    print(name)
    
    loc_df = group[['date_time', 'tempC']].set_index('date_time')
    
    five_years_line = vincent.Line(loc_df, width=300, height=150)
    five_years_line.axis_titles(x='Date', y='tempC')
    #five_years_line.display()
    
    five_years_vega = folium.Vega(five_years_line.to_json(), width=350, height=200)
    
    lat = name.split(',')[0]
    long = name.split(',')[1]
    
    marker = folium.Marker(
            location = [lat, long],
            fill_opacity = 0.8, color=None,
            fill_color = ('#274cc9'),
            popup = folium.Popup().add_child(five_years_vega),
            tooltip = '{}, {}'.format(lat, long)
            )

    marker.add_to(m)

m
# Out:
# -2.0139227777777777,107.21397888888889
# -3.710423888888889,107.58711333333333
# -34.335388333333334,121.58882138888889
# -34.92638611111111,118.75127666666667
# -35.0601225,115.86509861111111
# -37.84263361111111,135.63899666666666
# -37.86814888888889,144.92790333333332
# -38.33253472222223,144.90495305555555
# -38.85968833333334,142.90507805555555
# -5.2539613888888885,106.22705861111112
# -6.315075277777778,105.565575
# 0.7143913888888889,105.32447722222221
# 1.2206466666666669,103.86853722222222
# 1.3156586111111113,104.32543944444444
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-2.1.0.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_eda0ac50e1ff4067966ba6e38c5a6d03%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js%22%3E%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23vega_0de168ecb2fb431ab514783eb0f345b2%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20350.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20200.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Out:
# 'folium' is not recognized as an internal or external command,
# operable program or batch file.
